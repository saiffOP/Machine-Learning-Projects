# %%
import pandas as pd

# %%
series = pd.Series(["BMW", "Toyota", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
car_data = pd.DataFrame({"Company": series, "Colour": colours})
car_data
# Out:
#   Company Colour
# 0     BMW    Red
# 1  Toyota   Blue
# 2   Honda  White

# %%
car_Sales = pd.read_csv("car-sales.csv")
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_Sales.to_csv("exported-car-sales.csv", index = False)

# %%
exported_car_sales = pd.read_csv("exported-car-sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_Sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_Sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_Sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_Sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_Sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_Sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %% [markdown]
# # **Viewing and Selecting Data**

# %%
car_Sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_Sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
animals = pd.Series(["Cat", "Dog","Goat","Panda","Snake"], index=[0,3,9,8,3])
animals
# Out:
# 0      Cat
# 3      Dog
# 9     Goat
# 8    Panda
# 3    Snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      Dog
# 3    Snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_Sales[car_Sales["Make"] == "BMW"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_Sales[car_Sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_Sales["Make"], car_Sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_Sales.groupby("Make").mean
# Out:
# <bound method GroupBy.mean of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x787e42a45840>>

# %%
car_Sales.groupby(["Make"])["Doors"].mean()
# Out:
# Make
# BMW       5.00
# Honda     4.00
# Nissan    4.00
# Toyota    3.75
# Name: Doors, dtype: float64

# %%
car_Sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_Sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# car_Sales["Price"] = car_Sales["Price"].str.replace('[\$,]','', regex = True).astype(float)

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_Sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# # **Manipulating Data**

# %%
car_Sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     Bmw  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_Sales["Make"].str.capitalize()
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       Bmw
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].astype(int)

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White    150043    4.0   $4,000
# 1   Honda    Red     87899    4.0   $5,000
# 2  Toyota   Blue     92302    3.0   $7,000
# 3     BMW  Black     11179    5.0  $22,000
# 4  Nissan  White    213095    4.0   $3,500
# 5  Toyota  Green     92302    4.0   $4,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
seats_column = pd.Series([5,5,5,5,5])
car_Sales["Seats"] = seats_column
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    NaN
# 6   Honda   Blue          45698      4   7500.0    NaN
# 7   Honda   Blue          54738      4   7000.0    NaN
# 8  Toyota  White          60000      4   6250.0    NaN
# 9  Nissan  White          31600      4   9700.0    NaN

# %%
car_Sales["Seats"].fillna(5, inplace=True)
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   4000.0    5.0
# 1   Honda    Red          87899      4   5000.0    5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0
# 3     BMW  Black          11179      5  22000.0    5.0
# 4  Nissan  White         213095      4   3500.0    5.0
# 5  Toyota  Green          99213      4   4500.0    5.0
# 6   Honda   Blue          45698      4   7500.0    5.0
# 7   Honda   Blue          54738      4   7000.0    5.0
# 8  Toyota  White          60000      4   6250.0    5.0
# 9  Nissan  White          31600      4   9700.0    5.0

# %%
fuel_economy = [7.5, 9.5, 5.0, 6.6, 8.6, 8.5, 10, 6, 5, 7.4]
car_Sales["Fuel per 100km"] = fuel_economy
car_Sales['Fuel per 100km'].plot()
# Out:
# <Axes: >

# %%
car_Sales["Total Fuel Used (L)"] = car_Sales["Odometer (KM)"]/100 * car_Sales["Fuel per 100km"]
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.5
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             6.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.5
# 6   Honda   Blue          45698      4   7500.0    5.0            10.0
# 7   Honda   Blue          54738      4   7000.0    5.0             6.0
# 8  Toyota  White          60000      4   6250.0    5.0             5.0
# 9  Nissan  White          31600      4   9700.0    5.0             7.4
#
#    Total Fuel Used (L)
# 0            11253.225
# 1             8350.405
# 2             1627.450
# 3              737.814
# 4            18326.170
# 5             8433.105
# 6             4569.800
# 7             3284.280
# 8             3000.000
# 9             2338.400

# %%
car_Sales["No. of Tyres"] = 4
car_Sales["Passed road Safety"] = True
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.5
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             6.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.5
# 6   Honda   Blue          45698      4   7500.0    5.0            10.0
# 7   Honda   Blue          54738      4   7000.0    5.0             6.0
# 8  Toyota  White          60000      4   6250.0    5.0             5.0
# 9  Nissan  White          31600      4   9700.0    5.0             7.4
#
#    Total Fuel Used (L)  No. of Tyres  Passed road Safety
# 0            11253.225             4                True
# 1             8350.405             4                True
# 2             1627.450             4                True
# 3              737.814             4                True
# 4            18326.170             4                True
# 5             8433.105             4                True
# 6             4569.800             4                True
# 7             3284.280             4                True
# 8             3000.000             4                True
# 9             2338.400             4                True

# %%
car_sales_shuffled = car_Sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 3     BMW  Black          11179      5  22000.0    5.0             6.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.6
# 7   Honda   Blue          54738      4   7000.0    5.0             6.0
# 9  Nissan  White          31600      4   9700.0    5.0             7.4
# 5  Toyota  Green          99213      4   4500.0    5.0             8.5
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.5
# 8  Toyota  White          60000      4   6250.0    5.0             5.0
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 6   Honda   Blue          45698      4   7500.0    5.0            10.0
#
#    Total Fuel Used (L)  No. of Tyres  Passed road Safety
# 3              737.814             4                True
# 4            18326.170             4                True
# 7             3284.280             4                True
# 9             2338.400             4                True
# 5             8433.105             4                True
# 0            11253.225             4                True
# 1             8350.405             4                True
# 8             3000.000             4                True
# 2             1627.450             4                True
# 6             4569.800             4                True

# %%
car_Sales = car_Sales.sort_index()

# %%
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.5
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             6.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.5
# 6   Honda   Blue          45698      4   7500.0    5.0            10.0
# 7   Honda   Blue          54738      4   7000.0    5.0             6.0
# 8  Toyota  White          60000      4   6250.0    5.0             5.0
# 9  Nissan  White          31600      4   9700.0    5.0             7.4
#
#    Total Fuel Used (L)  No. of Tyres  Passed road Safety
# 0            11253.225             4                True
# 1             8350.405             4                True
# 2             1627.450             4                True
# 3              737.814             4                True
# 4            18326.170             4                True
# 5             8433.105             4                True
# 6             4569.800             4                True
# 7             3284.280             4                True
# 8             3000.000             4                True
# 9             2338.400             4                True

# %%
car_Sales["Odometer (M)"] = car_Sales["Odometer (KM)"].apply(lambda x: x / 1.6)
car_Sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100km  \
# 0  Toyota  White         150043      4   4000.0    5.0             7.5
# 1   Honda    Red          87899      4   5000.0    5.0             9.5
# 2  Toyota   Blue          32549      3   7000.0    5.0             5.0
# 3     BMW  Black          11179      5  22000.0    5.0             6.6
# 4  Nissan  White         213095      4   3500.0    5.0             8.6
# 5  Toyota  Green          99213      4   4500.0    5.0             8.5
# 6   Honda   Blue          45698      4   7500.0    5.0            10.0
# 7   Honda   Blue          54738      4   7000.0    5.0             6.0
# 8  Toyota  White          60000      4   6250.0    5.0             5.0
# 9  Nissan  White          31600      4   9700.0    5.0             7.4
#
#    Total Fuel Used (L)  No. of Tyres  Passed road Safety  Odometer (M)
# 0            11253.225             4                True     93776.875
# 1             8350.405             4                True     54936.875
# 2             1627.450             4                True     20343.125
# 3              737.814             4                True      6986.875
# 4            18326.170             4                True    133184.375
# 5             8433.105             4                True     62008.125
# 6             4569.800             4                True     28561.250
# 7             3284.280             4                True     34211.250
# 8             3000.000             4                True     37500.000
# 9             2338.400             4                True     19750.000
